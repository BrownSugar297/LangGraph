# %%
from langgraph.graph import StateGraph, START, END, add_messages
from typing import TypedDict, Annotated, List
from langgraph.checkpoint.memory import MemorySaver
from langchain_groq import ChatGroq
from langchain_community.tools import TavilySearchResults
from langgraph.prebuilt import ToolNode
from langchain_core.messages import HumanMessage

memory = MemorySaver()

search_tool = TavilySearchResults(max_results=2)
tools = [search_tool]

llm = ChatGroq(model="llama-3.1-8b-instant")
llm_with_tools = llm.bind_tools(tools=tools)

class BasicState(TypedDict): 
    messages: Annotated[List, add_messages]

def model(state: BasicState): 
    return {
        "messages": [llm_with_tools.invoke(state["messages"])]
    }

def tools_router(state: BasicState): 
    last_message = state["messages"][-1]
    if(hasattr(last_message, "tool_calls") and 
    len(last_message.tool_calls) > 0):
        return "tools"
    else: 
        return END


graph = StateGraph(BasicState)
graph.add_node(model, "model")
graph.add_node("tools", ToolNode(tools=tools))

graph.set_entry_point("model")
graph.add_conditional_edges("model", tools_router)

graph.add_edge("tools", "model")

app = graph.compile(checkpointer=memory, interrupt_before=["tools"])

# %%
from IPython.display import Image, display

display(Image(app.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {
    "thread_id": 1
}}

events = app.stream({
    "messages": [HumanMessage(content="What is the current weather in DHAKA?")]
}, config=config, stream_mode="values")

for event in events:
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the current weather in DHAKA?
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (bq19pwfhy)
#  Call ID: bq19pwfhy
#   Args:
#     query: current weather in Dhaka

# %%
snapshot = app.get_state(config=config)
snapshot.next
# Out:
# ('tools',)

# %%
events = app.stream(None, config, stream_mode="values")
for event in events:
    event["messages"][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search_results_json (bq19pwfhy)
#  Call ID: bq19pwfhy
#   Args:
#     query: current weather in Dhaka
# ================================= Tool Message =================================
# Name: tavily_search_results_json
#
# [{"title": "Dhaka weather in March 2026 - Weather25.com", "url": "https://www.weather25.com/asia/bangladesh/dhaka?page=month&month=March", "content": "| 29 Patchy light rain with thunder 34° /22° | 30 Light rain shower 31° /22° | 31 Thundery outbreaks possible 34° /24° |  |  |  |  | [...] weather25.com\nSearch\nweather in Bangladesh\nRemove from your favorite locations\nAdd to my locations\nShare\nweather in Bangladesh\n\n# Dhaka weather in March 2026\n\nPartly cloudy\nClear\nClear\nPartly cloudy\nPatchy light rain with thunder\nLight rain shower\nThundery outbreaks possible\nClear\nClear\nThundery outbreaks possible\nThundery outbreaks possible\nPatchy light rain with thunder\nPatchy light rain with thunder\nPatchy rain possible\n\n## The average weather in Dhaka in March\n\nThe weather in Dhaka in March is very hot. The average temperatures are between 23°C and 36°C, drinking water regularly is advisable.\n\nYou can expect a few rainy days in Dhaka during March, but usually the weather is comfortable in March. [...] Sunny\nSunny\nSunny\nSunny\nPartly cloudy\nSunny\nSunny\nSunny\nSunny\nSunny\nSunny\nSunny\nSunny\nPartly cloudy\nPartly cloudy\nPartly cloudy\nPartly cloudy\nPartly cloudy\nSunny\nSunny\nPartly cloudy\nPartly cloudy\nPartly cloudy\nSunny\nPartly cloudy\nSunny\nSunny\nPartly cloudy\nPatchy light rain with thunder\nLight rain shower\nThundery outbreaks possible\n\n## Explore the weather in Dhaka in other months\n\n## Dhaka annual weather", "score": 0.9999722}, {"title": "Weather Dhaka in March 2026: Temperature & Climate", "url": "https://en.climate-data.org/asia/bangladesh/dhaka-division/dhaka-1062098/t/march-3/", "content": "## Climate for Dhaka in March\n\nClimograph, Dhaka\n\nDuring March, Dhaka records its highest daily temperature on 22.03 at 32.8°C | 91.1°F,\nand the lowest on 01.03, with 17.2°C | 63°F.\nIn the first part of the month, average highs are 30.4°C | 86.7°F and lows 18.2°C | 64.8°F.\nThe second third shows similar highs at 31.9°C | 89.4°F, while lows hover near 20.1°C | 68.2°F.\nThe final days bring highs of 32.4°C | 90.3°F and lows of 21.7°C | 71.1°F.\nThe hottest 10-day period is 21-31 with highs averaging 26.9°C | 80.4°F,\nand the coldest occurs between 1-10, with lows near 24.4°C | 75.9°F. [...] Humidity in Dhaka during March ranges from a low of 23% to a high of 28%.\nThe most humid day is 22.03 with 28%, and the driest is 27.03, at just 23%.\nThe average humidity is 26% in early March, 26% mid-month, and 27% at month’s end.\nHumidity peaks from 21-31 and dips lowest from 1-10.\n\n## Dhaka weather by month [...] In the early part of the month, average high temperatures are 30.4°C | 86.7°F, and lows are about 18.2°C | 64.8°F. Between days 11 and 20, highs average 31.9°C | 89.4°F with lows at 20.1°C | 68.2°F. Toward the end of the month, highs are near 32.4°C | 90.3°F and lows fall to 21.7°C | 71.1°F.\n\n#### What 10-day period during March shows the highest temperature values in Dhaka?\n\nHigh temperatures average 26.9°C | 80.4°F during the warmest 10-day period, which runs from 21-31.\n\n#### What 10-day period during March shows the lowest temperature values in Dhaka?\n\nThe coldest 10-day window, with lows of 24.4°C | 75.9°F, spans from 1-10.\n\n## Dhaka weather and climate for further months\n\n## Dhaka weather in March // weather averages", "score": 0.99991965}]
# ================================== Ai Message ==================================
#
# The current weather in Dhaka is very hot, with average temperatures ranging from 23°C to 36°C. It can be expected that there will be a few rainy days in Dhaka during March, but usually, the weather is comfortable. The average humidity in Dhaka during March ranges from 23% to 28%. The hottest 10-day period is from 21-31, with highs averaging 26.9°C | 80.4°F, and the coldest 10-day period is from 1-10, with lows near 24.4°C | 75.9°F.
